# %%
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
import pandas as pd

# %%
data = pd.read_csv('train.csv')

# %%
data = data.dropna()

# %%
data.head()
# Out:
#     loan_amnt        term  int_rate  installment grade sub_grade  \
# 3      4200.0   36 months     13.33       142.19     C        C3
# 7     14000.0   36 months     15.31       487.45     C        C2
# 12    20000.0   36 months     11.99       664.20     B        B3
# 16     8650.0   36 months     12.12       287.80     B        B3
# 17    25000.0   60 months     17.27       624.95     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc    ...      \
# 3             Receptionist   < 1 year       MORTGAGE     21600.0    ...
# 7   Department of the Army  10+ years       MORTGAGE     96000.0    ...
# 12     Sr. Specialist, Tax  10+ years           RENT    110000.0    ...
# 16           Haven Hospice    8 years           RENT     76000.0    ...
# 17   Cheney Public Schools    6 years       MORTGAGE    108000.0    ...
#
#    total_acc initial_list_status  collections_12_mths_ex_med policy_code  \
# ...

# %%
data.hist(figsize=(30,12));

# %%
sns.boxplot(data['installment']);

# %%
sns.boxplot(data['int_rate']);

# %%
sns.boxplot(data['dti']);

# %%
# data['term'].value_counts()
sns.countplot(data['term']);

# %%
sns.countplot(data['addr_state']);

# %%
sns.countplot(data[data['addr_state'].isin(data['addr_state'].value_counts().head().index)]['addr_state'])

# %%
plt.scatter(data['loan_amnt'], data['installment']);

# %%
corr_matrix = data.drop(['policy_code'], axis=1).corr()
sns.heatmap(corr_matrix);

# %%
sns.boxplot(x='grade', y='loan_amnt', data=data);
# sns.boxplot(x='sub_grade', y='loan_amnt', data=data);

# %%
sns.pairplot(data[['loan_amnt', 'installment']]);
