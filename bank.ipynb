# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#     loan_amnt        term  int_rate  installment grade sub_grade  \
# 3      4200.0   36 months     13.33       142.19     C        C3
# 7     14000.0   36 months     15.31       487.45     C        C2
# 12    20000.0   36 months     11.99       664.20     B        B3
# 16     8650.0   36 months     12.12       287.80     B        B3
# 17    25000.0   60 months     17.27       624.95     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 3             Receptionist   < 1 year       MORTGAGE     21600.0  ...
# 7   Department of the Army  10+ years       MORTGAGE     96000.0  ...
# 12     Sr. Specialist, Tax  10+ years           RENT    110000.0  ...
# 16           Haven Hospice    8 years           RENT     76000.0  ...
# 17   Cheney Public Schools    6 years       MORTGAGE    108000.0  ...
#
#    total_acc initial_list_status  collections_12_mths_ex_med policy_code  \
# 3       19.0                   w                         0.0         1.0
# 7       29.0                   f                         0.0         1.0
# 12      35.0                   f                         0.0         1.0
# 16      20.0                   f                         0.0         1.0
# 17      40.0                   f                         0.0         1.0
#
#    application_type acc_now_delinq tot_coll_amt  tot_cur_bal  \
# 3        INDIVIDUAL            0.0        165.0      28187.0
# 7        INDIVIDUAL            0.0          0.0     276267.0
# 12       INDIVIDUAL            0.0          0.0      41806.0
# 16       INDIVIDUAL            0.0          0.0     614403.0
# 17       INDIVIDUAL            0.0          0.0     337866.0
#
#     total_rev_hi_lim  record_id
# 3            14500.0  453447199
# 7            39700.0  453322484
# 12           54600.0  453423047
# 16           10000.0  453286318
# 17           23800.0  453277374
#
# [5 rows x 36 columns]

# %%
data = data.dropna()
numeric_data = data.drop(['emp_title', 'home_ownership', 'record_id', 'pymnt_plan', 'earliest_cr_line', 'emp_length', 'grade', 'sub_grade', 'application_type', 'issue_d', 'zip_code', 'policy_code', 'verification_status', 'purpose', 'initial_list_status', 'addr_state'], axis=1)
# numeric_data = numeric_data.sort_values(['emp_length'])
numeric_data['term'] = pd.factorize(numeric_data['term'])[0]
# numeric_data['emp_length'] = pd.factorize(numeric_data['emp_length'])[0]

# %%
numeric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69010 entries, 3 to 200188
# Data columns (total 20 columns):
# loan_amnt                     69010 non-null float64
# term                          69010 non-null int64
# int_rate                      69010 non-null float64
# installment                   69010 non-null float64
# annual_inc                    69010 non-null float64
# loan_status                   69010 non-null int64
# dti                           69010 non-null float64
# delinq_2yrs                   69010 non-null float64
# inq_last_6mths                69010 non-null float64
# mths_since_last_delinq        69010 non-null float64
# open_acc                      69010 non-null float64
# pub_rec                       69010 non-null float64
# revol_bal                     69010 non-null float64
# revol_util                    69010 non-null float64
# total_acc                     69010 non-null float64
# collections_12_mths_ex_med    69010 non-null float64
# acc_now_delinq                69010 non-null float64
# tot_coll_amt                  69010 non-null float64
# tot_cur_bal                   69010 non-null float64
# total_rev_hi_lim              69010 non-null float64
# dtypes: float64(18), int64(2)
# memory usage: 11.1 MB

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


for idx, feature in enumerate(numeric_data.columns):
    numeric_data.plot(feature, 'annual_inc', subplots=True, kind="scatter")

# %%
numeric_data.corr()
# Out:
#                             loan_amnt      term  int_rate  installment  \
# loan_amnt                    1.000000  0.419079  0.207200     0.956240
# term                         0.419079  1.000000  0.476435     0.179839
# int_rate                     0.207200  0.476435  1.000000     0.185929
# installment                  0.956240  0.179839  0.185929     1.000000
# annual_inc                   0.331844  0.064264 -0.042272     0.326908
# loan_status                 -0.088639 -0.163852 -0.227392    -0.070348
# dti                          0.014448  0.065962  0.138871     0.012320
# delinq_2yrs                  0.015918  0.003740  0.048905     0.022244
# inq_last_6mths              -0.002139  0.021812  0.244733     0.022352
# mths_since_last_delinq      -0.045005 -0.021351 -0.051393    -0.047534
# open_acc                     0.164705  0.062261 -0.008830     0.156608
# pub_rec                     -0.084529 -0.017880  0.050516    -0.077405
# revol_bal                    0.322258  0.085757 -0.005866     0.314118
# revol_util                   0.113615  0.048689  0.213826     0.132536
# total_acc                    0.179799  0.082595 -0.034667     0.162616
# collections_12_mths_ex_med  -0.004409  0.009625  0.024280    -0.004108
# acc_now_delinq               0.014012  0.014615  0.034284     0.016051
# tot_coll_amt                -0.015747 -0.003611 -0.001015    -0.016099
# tot_cur_bal                  0.287614  0.102576 -0.076956     0.260773
# total_rev_hi_lim             0.329247  0.080900 -0.134928     0.306071
#
#                             annual_inc  loan_status       dti  delinq_2yrs  \
# loan_amnt                     0.331844    -0.088639  0.014448     0.015918
# term                          0.064264    -0.163852  0.065962     0.003740
# int_rate                     -0.042272    -0.227392  0.138871     0.048905
# installment                   0.326908    -0.070348  0.012320     0.022244
# annual_inc                    1.000000     0.051448 -0.218072     0.047132
# loan_status                   0.051448     1.000000 -0.136949    -0.041271
# dti                          -0.218072    -0.136949  1.000000     0.001057
# delinq_2yrs                   0.047132    -0.041271  0.001057     1.000000
# inq_last_6mths                0.058471    -0.040288 -0.005441     0.010379
# mths_since_last_delinq       -0.059079     0.033311  0.008214    -0.572795
# open_acc                      0.102731    -0.027063  0.269412     0.053278
# pub_rec                      -0.017564    -0.005599 -0.054795    -0.044972
# revol_bal                     0.331312     0.005325  0.110326    -0.008609
# revol_util                    0.043398    -0.066880  0.156861    -0.019327
# total_acc                     0.159722     0.025307  0.195443     0.090099
# collections_12_mths_ex_med    0.000711    -0.014905 -0.004855     0.040895
# acc_now_delinq                0.017155    -0.017302  0.010475     0.104517
# tot_coll_amt                  0.007769     0.004174 -0.025004    -0.021791
# tot_cur_bal                   0.462450     0.059417 -0.045734     0.063681
# total_rev_hi_lim              0.307140     0.037817  0.057436    -0.005312
#
#                             inq_last_6mths  mths_since_last_delinq  open_acc  \
# loan_amnt                        -0.002139               -0.045005  0.164705
# term                              0.021812               -0.021351  0.062261
# int_rate                          0.244733               -0.051393 -0.008830
# installment                       0.022352               -0.047534  0.156608
# annual_inc                        0.058471               -0.059079  0.102731
# loan_status                      -0.040288                0.033311 -0.027063
# dti                              -0.005441                0.008214  0.269412
# delinq_2yrs                       0.010379               -0.572795  0.053278
# inq_last_6mths                    1.000000                0.012680  0.117040
# mths_since_last_delinq            0.012680                1.000000 -0.038754
# open_acc                          0.117040               -0.038754  1.000000
# pub_rec                           0.054304                0.103803 -0.030540
# revol_bal                        -0.015696               -0.025355  0.212104
# revol_util                       -0.091848                0.018126 -0.140806
# total_acc                         0.141998               -0.059135  0.646499
# collections_12_mths_ex_med        0.001743               -0.039365  0.010627
# acc_now_delinq                   -0.006955               -0.134521  0.020432
# tot_coll_amt                      0.010750                0.024644  0.005044
# tot_cur_bal                       0.043393               -0.089239  0.196705
# total_rev_hi_lim                  0.016165               -0.038240  0.357078
#
#                              pub_rec  revol_bal  revol_util  total_acc  \
# loan_amnt                  -0.084529   0.322258    0.113615   0.179799
# term                       -0.017880   0.085757    0.048689   0.082595
# int_rate                    0.050516  -0.005866    0.213826  -0.034667
# installment                -0.077405   0.314118    0.132536   0.162616
# annual_inc                 -0.017564   0.331312    0.043398   0.159722
# loan_status                -0.005599   0.005325   -0.066880   0.025307
# dti                        -0.054795   0.110326    0.156861   0.195443
# delinq_2yrs                -0.044972  -0.008609   -0.019327   0.090099
# inq_last_6mths              0.054304  -0.015696   -0.091848   0.141998
# mths_since_last_delinq      0.103803  -0.025355    0.018126  -0.059135
# open_acc                   -0.030540   0.212104   -0.140806   0.646499
# pub_rec                     1.000000  -0.101925   -0.093386   0.006802
# revol_bal                  -0.101925   1.000000    0.228773   0.166828
# revol_util                 -0.093386   0.228773    1.000000  -0.090234
# total_acc                   0.006802   0.166828   -0.090234   1.000000
# collections_12_mths_ex_med  0.020142  -0.010707   -0.038248   0.002515
# acc_now_delinq             -0.002232   0.006600   -0.038554   0.022316
# tot_coll_amt                0.035567  -0.026433   -0.044491   0.027229
# tot_cur_bal                -0.076204   0.404487    0.097736   0.249145
# total_rev_hi_lim           -0.103226   0.827475   -0.126425   0.265029
#
#                             collections_12_mths_ex_med  acc_now_delinq  \
# loan_amnt                                    -0.004409        0.014012
# term                                          0.009625        0.014615
# int_rate                                      0.024280        0.034284
# installment                                  -0.004108        0.016051
# annual_inc                                    0.000711        0.017155
# loan_status                                  -0.014905       -0.017302
# dti                                          -0.004855        0.010475
# delinq_2yrs                                   0.040895        0.104517
# inq_last_6mths                                0.001743       -0.006955
# mths_since_last_delinq                       -0.039365       -0.134521
# open_acc                                      0.010627        0.020432
# pub_rec                                       0.020142       -0.002232
# revol_bal                                    -0.010707        0.006600
# revol_util                                   -0.038248       -0.038554
# total_acc                                     0.002515        0.022316
# collections_12_mths_ex_med                    1.000000        0.026809
# acc_now_delinq                                0.026809        1.000000
# tot_coll_amt                                  0.051547       -0.002398
# tot_cur_bal                                  -0.001770        0.026705
# total_rev_hi_lim                             -0.005966        0.033163
#
#                             tot_coll_amt  tot_cur_bal  total_rev_hi_lim
# loan_amnt                      -0.015747     0.287614          0.329247
# term                           -0.003611     0.102576          0.080900
# int_rate                       -0.001015    -0.076956         -0.134928
# installment                    -0.016099     0.260773          0.306071
# annual_inc                      0.007769     0.462450          0.307140
# loan_status                     0.004174     0.059417          0.037817
# dti                            -0.025004    -0.045734          0.057436
# delinq_2yrs                    -0.021791     0.063681         -0.005312
# inq_last_6mths                  0.010750     0.043393          0.016165
# mths_since_last_delinq          0.024644    -0.089239         -0.038240
# open_acc                        0.005044     0.196705          0.357078
# pub_rec                         0.035567    -0.076204         -0.103226
# revol_bal                      -0.026433     0.404487          0.827475
# revol_util                     -0.044491     0.097736         -0.126425
# total_acc                       0.027229     0.249145          0.265029
# collections_12_mths_ex_med      0.051547    -0.001770         -0.005966
# acc_now_delinq                 -0.002398     0.026705          0.033163
# tot_coll_amt                    1.000000     0.002389         -0.021927
# tot_cur_bal                     0.002389     1.000000          0.360682
# total_rev_hi_lim               -0.021927     0.360682          1.000000

# %% [markdown]
# * Общий баланс кредита коррелирует с кредитным лимитом.
# * Ежемесячный взнос коррелирует с суммой кредита.

# %%
from sklearn.preprocessing import scale
from sklearn.utils import shuffle
from sklearn.linear_model import LinearRegression


df_shuffled = shuffle(numeric_data, random_state=123)
X = scale(df_shuffled.drop(['annual_inc'], axis=1))
y = df_shuffled['annual_inc']
# Out:
# /home/anna/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
#   import sys

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(X, y)
list(zip(numeric_data.drop(['annual_inc'], axis=1), linear_regressor.coef_))
# Out:
# [('loan_amnt', 12169.209024766993),
#  ('term', -2923.8740412988336),
#  ('int_rate', -1041.1329629498612),
#  ('installment', 401.7013869408215),
#  ('loan_status', 553.7933011640572),
#  ('dti', -13504.412779734928),
#  ('delinq_2yrs', 1045.067101819699),
#  ('inq_last_6mths', 2561.7393680778255),
#  ('mths_since_last_delinq', -434.5256036103716),
#  ('open_acc', -332.0431517683791),
#  ('pub_rec', 1559.0350448133138),
#  ('revol_bal', 10367.61192904928),
#  ('revol_util', 57.93718611709783),
#  ('total_acc', 3683.395434349142),
#  ('collections_12_mths_ex_med', 104.87801517185014),
#  ('acc_now_delinq', 319.32025716373806),
#  ('tot_coll_amt', 364.5374789365139),
#  ('tot_cur_bal', 18716.820862413893),
#  ('total_rev_hi_lim', -1071.990349741549)]

# %%
from sklearn.linear_model import Lasso


alphas = np.arange(1, 200, 50)
coefs_lasso = np.zeros((alphas.shape[0], X.shape[1])) 

for row_index, row in enumerate(coefs_lasso):
    regressor = Lasso(alphas[row_index])
    regressor.fit(X, y)
    for i, _ in enumerate(row):
        row[i] = regressor.coef_[i]
print(coefs_lasso[1])
# Out:
# [ 11153.27364435  -2611.95333389  -1026.06547631   1249.42666314
#     517.75313489 -13467.1330469    1023.0217769    2478.81341199
#    -392.6532836    -256.08344779   1509.50264812   9954.84416611
#     113.86064056   3567.51044212     56.52584472    262.00497148
#     321.04095232  18730.42583122   -624.26301008]

# %%
plt.figure(figsize=(8, 5))
for coef, feature in zip(coefs_lasso.T, numeric_data.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")
# Out:
# Text(0.5, 1.0, 'Lasso')
